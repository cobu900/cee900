# %%
# To bring in the libraries:
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Bring in the file:
df = pd.read_csv(r"C:\Users\user\Desktop\energydata_complete.csv")

# %%
df.head(6)
# Out:
#                   date  Appliances  lights     T1       RH_1    T2       RH_2  \
# 0  2016-01-11 17:00:00          60      30  19.89  47.596667  19.2  44.790000
# 1  2016-01-11 17:10:00          60      30  19.89  46.693333  19.2  44.722500
# 2  2016-01-11 17:20:00          50      30  19.89  46.300000  19.2  44.626667
# 3  2016-01-11 17:30:00          50      40  19.89  46.066667  19.2  44.590000
# 4  2016-01-11 17:40:00          60      40  19.89  46.333333  19.2  44.530000
# 5  2016-01-11 17:50:00          50      40  19.89  46.026667  19.2  44.500000
#
#       T3       RH_3         T4  ...         T9   RH_9     T_out  Press_mm_hg  \
# 0  19.79  44.730000  19.000000  ...  17.033333  45.53  6.600000        733.5
# 1  19.79  44.790000  19.000000  ...  17.066667  45.56  6.483333        733.6
# 2  19.79  44.933333  18.926667  ...  17.000000  45.50  6.366667        733.7
# 3  19.79  45.000000  18.890000  ...  17.000000  45.40  6.250000        733.8
# ...

# %%
df.drop(['date','lights'], axis = 1, inplace = True)
df
# Out:
#        Appliances         T1       RH_1         T2       RH_2         T3  \
# 0              60  19.890000  47.596667  19.200000  44.790000  19.790000
# 1              60  19.890000  46.693333  19.200000  44.722500  19.790000
# 2              50  19.890000  46.300000  19.200000  44.626667  19.790000
# 3              50  19.890000  46.066667  19.200000  44.590000  19.790000
# 4              60  19.890000  46.333333  19.200000  44.530000  19.790000
# ...           ...        ...        ...        ...        ...        ...
# 19730         100  25.566667  46.560000  25.890000  42.025714  27.200000
# 19731          90  25.500000  46.500000  25.754000  42.080000  27.133333
# 19732         270  25.500000  46.596667  25.628571  42.768571  27.050000
# 19733         420  25.500000  46.990000  25.414000  43.036000  26.890000
# 19734         430  25.500000  46.600000  25.264286  42.971429  26.823333
#
#             RH_3         T4       RH_4         T5  ...         T9     RH_9  \
# ...

# %%
# Normalize the df. import library
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()
scaled_features = [feature for feature in df.columns]
scaled_data = scaler.fit_transform(df)
transformed_df = pd.DataFrame(data = scaled_data, columns = scaled_features)

# %%
transformed_df
# Out:
#        Appliances        T1      RH_1        T2      RH_2        T3      RH_3  \
# 0        0.046729  0.327350  0.566187  0.225345  0.684038  0.215188  0.746066
# 1        0.046729  0.327350  0.541326  0.225345  0.682140  0.215188  0.748871
# 2        0.037383  0.327350  0.530502  0.225345  0.679445  0.215188  0.755569
# 3        0.037383  0.327350  0.524080  0.225345  0.678414  0.215188  0.758685
# 4        0.046729  0.327350  0.531419  0.225345  0.676727  0.215188  0.758685
# ...           ...       ...       ...       ...       ...       ...       ...
# 19730    0.084112  0.926786  0.537657  0.711655  0.606309  0.830841  0.579374
# 19731    0.074766  0.919747  0.536006  0.701769  0.607836  0.825302  0.582178
# 19732    0.242991  0.919747  0.538666  0.692651  0.627198  0.818378  0.603988
# 19733    0.383178  0.919747  0.549491  0.677054  0.634717  0.805085  0.585294
# 19734    0.392523  0.919747  0.538758  0.666171  0.632902  0.799546  0.579062
#
# ...

# %%
# slipt transformed_df
x = transformed_df.drop('Appliances', axis = 1)
y = transformed_df[['Appliances']]

# %%
# No 17.
# Sampled features:
sampled_data = x
pulled_data = sampled_data[['T2', 'T6']]
pulled_data
# Out:
#              T2        T6
# 0      0.225345  0.381070
# 1      0.225345  0.375443
# 2      0.225345  0.367487
# 3      0.225345  0.363800
# 4      0.225345  0.361859
# ...         ...       ...
# 19730  0.711655  0.898317
# 19731  0.701769  0.880852
# 19732  0.692651  0.864260
# 19733  0.677054  0.829525
# 19734  0.666171  0.788580
#
# [19735 rows x 2 columns]

# %%
from sklearn.model_selection import train_test_split
# Reshape the arrays for compatibility:
# Split them:
x1 = pulled_data['T2'].values.reshape(-1,1)
y1 = pulled_data['T6'].values.reshape(-1,1)
x1_train, x1_test, y1_train, y1_test = train_test_split(x1, y1, test_size = 0.3, random_state = 42)

# %%
y1_pred = lin_model.predict(x1_test)
y1_pred
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 y1_pred = lin_model.predict(x1_test)
#       2 y1_pred
#
# File ~\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py:386, in LinearModel.predict(self, X)
#     372 def predict(self, X):
#     373     """
#     374     Predict using the linear model.
#     375
#    (...)
#     384         Returns predicted values.
#     385     """
# --> 386     return self._decision_function(X)
#
# File ~\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py:369, in LinearModel._decision_function(self, X)
#     366 def _decision_function(self, X):
#     367     check_is_fitted(self)
# ...

# %%
# Train, using Linear Regressor
from sklearn.linear_model import LinearRegression
lin_model =  LinearRegression()
lin_model.fit(x1_train, y1_train)
# Out:
# LinearRegression()

# %%
# mean_square_ error
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y1_test, y1_pred)
rmse = np.sqrt(mse)
print(f'Root Mean Square Error: {rmse:.3f}')
# Out:
# Root Mean Square Error: 0.106

# %%
# No 18
lin_model =  LinearRegression()
lin_model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lin_model.predict(x_test)
y_pred
# Out:
# array([[0.03322207],
#        [0.24411599],
#        [0.03400024],
#        ...,
#        [0.06844707],
#        [0.10032325],
#        [0.05722198]])

# %%
# No.18
# Mean Absolute Error (MAE)
from sklearn.metrics import mean_absolute_error
MAE = mean_absolute_error(y_test, y_pred)
print(f"Mean Absolute Error: {MAE:.3f}")
# Out:
# Mean Absolute Error: 0.050

# %%
# No.19
# mean_square_ error
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
print(f"Root Mean Square Error: {rmse:.3f}")
# Out:
# Root Mean Square Error: 0.088

# %%
# 20.
# Mean Absolute Error (MAE)
from sklearn.metrics import mean_absolute_error
MAE = mean_absolute_error(y_test, y_pred)
print(f"Mean Absolute Error: {MAE:.3f}")
# Out:
# Mean Absolute Error: 0.050

# %%
# No 22.
# seen data
seen_data_score = lin_model.score(x_train, y_train)
print(f'SDS: {seen_data_score:.3f}')
# Out:
# SDS: 0.145

# %%
# unseen data
unseen_data_score = lin_model.score(x_test,y_test)
print(f'UDS: {unseen_data_score:.3f}')
# Out:
# UDS: 0.149

# %%
# No 23.

# performing ridge regression at alpha = 0.4
from sklearn.linear_model import Ridge
ridge_model = Ridge(alpha = 0.4)
ridge_model.fit(x_train, y_train)
ridge_model.coef_
# Out:
# array([[-0.01840621,  0.5195253 , -0.20139673, -0.41107123,  0.28808681,
#          0.0951346 ,  0.02738389,  0.02457853, -0.01985322,  0.01615237,
#          0.21729178,  0.03551862,  0.01009781, -0.04597696,  0.10102815,
#         -0.15683005, -0.1889163 , -0.04136654, -0.26217227,  0.00658387,
#         -0.05472365,  0.03026762,  0.01207649,  0.08312757,  0.00074817,
#          0.00074817]])

# %%
#  root mean_square_ error
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
print(f'Root Mean Square Error: {rmse:.3f}')
# Out:
# Root Mean Square Error: 0.088

# %%
# Ridge Regression 
def weights(model, feat, col_name):
    # Flatten the coefficients array:
    coef_flat = ridge_model.coef_.flatten()
    
    # Create a Series with feature names as index and coefficients as values:
    wt= pd.Series(coef_flat, feat.columns).sort_values()
    
    # Create a DataFrame from the Series:
    wt_df=pd.DataFrame(wt).reset_index()
    wt_df.columns =['features', col_name]
    return wt_df
